# %% [markdown]
# <a href="https://colab.research.google.com/github/lehuyphuong/Vanishing_gradient/blob/feature%2Fadd_solution_project_vanishing_gradient/model_updated_by_normalization_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Import library

# %%
import random
import torch
import torch.optim as optim
import torchvision
import torchvision.transforms as transforms
from torch import nn
from torch.utils.data import Dataset, DataLoader, random_split
from torchvision.datasets import FashionMNIST
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ### Set up random seed

# %%
def set_seed(seed):
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False


SEED = 42
set_seed(SEED)

# %% [markdown]
# ### Download dataset

# %%
# download dataset
train_dataset = FashionMNIST('/content/drive/MyDrive/AIO_2024/Module_5/Week_4/data', train=True,
                             download=True,
                             transform=transforms.ToTensor())

test_dataset = FashionMNIST('/content/drive/MyDrive/AIO_2024/Module_5/Week_4/data', train=False,
                            download=True,
                            transform=transforms.ToTensor())

# %% [markdown]
# ### Split dataset

# %%
batch_size = 512


train_ratio = 0.9
train_size = int(len(train_dataset)*train_ratio)
val_size = len(train_dataset) - train_size

train_subnet, val_subnet = random_split(train_dataset, [train_size, val_size])
train_loader = DataLoader(train_subnet, batch_size=batch_size, shuffle=True)

val_loader = DataLoader(val_subnet, batch_size=batch_size, shuffle=False)
test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False)

print(f"Train size: {len(train_subnet)}")
print(f"Val size: {len(val_subnet)}")
print(f"Test size: {len(test_dataset)}")
# Out:
# Train size: 54000
# Val size: 6000
# Test size: 10000

# %% [markdown]
# ### Define model

# %%
device = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')
class MLP(nn.Module):
    def __init__(self, input_dims, hidden_dims, output_dims):
        super().__init__()
        self.layer1 = nn.Linear(input_dims, hidden_dims)
        self.layer2 = nn.Linear(hidden_dims, hidden_dims)
        self.layer3 = nn.Linear(hidden_dims, hidden_dims)
        self.layer4 = nn.Linear(hidden_dims, hidden_dims)
        self.layer5 = nn.Linear(hidden_dims, hidden_dims)
        self.layer6 = nn.Linear(hidden_dims, hidden_dims)
        self.layer7 = nn.Linear(hidden_dims, hidden_dims)
        self.output = nn.Linear(hidden_dims, output_dims)
        self.hidden_dims = hidden_dims

        for module in self.modules():
          if isinstance(module, nn.Linear):
            nn.init.normal_(module.weight, mean=0.0, std=1.0)
            nn.init.constant_(module.bias, 0.0)

    def forward(self, x):
        x = nn.Flatten()(x)
        x = self.layer1(x)
        x = nn.BatchNorm1d(self.hidden_dims)(x)
        x = nn.Sigmoid()(x)
        x = self.layer2(x)
        x = nn.BatchNorm1d(self.hidden_dims)(x)
        x = nn.Sigmoid()(x)
        x = self.layer3(x)
        x = nn.BatchNorm1d(self.hidden_dims)(x)
        x = nn.Sigmoid()(x)
        x = self.layer4(x)
        x = nn.BatchNorm1d(self.hidden_dims)(x)
        x = nn.Sigmoid()(x)
        x = self.layer5(x)
        x = nn.BatchNorm1d(self.hidden_dims)(x)
        x = nn.Sigmoid()(x)
        x = self.layer6(x)
        x = nn.BatchNorm1d(self.hidden_dims)(x)
        x = nn.Sigmoid()(x)
        x = self.layer7(x)
        x = nn.BatchNorm1d(self.hidden_dims)(x)
        x = nn.Sigmoid()(x)
        out = self.output(x)

        return out


input_dims = 784
hidden_dims = 128
output_dims = 10
lr = 1e-2
model = MLP(input_dims=input_dims, hidden_dims=hidden_dims,
            output_dims=output_dims).to(device)

criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=lr)

# %% [markdown]
# ### Train model

# %%
# train model
epochs = 100
train_loss_lst = []
train_acc_lst = []
val_loss_lst = []
val_acc_lst = []
for epoch in range(epochs):
    train_loss = 0.0
    train_acc = 0.0
    count = 0

    model.train()
    for X_train, y_train in train_loader:
        X_train, y_train = X_train.to(device), y_train.to(device)
        optimizer.zero_grad()
        outputs = model(X_train)
        loss = criterion(outputs, y_train)
        loss.backward()
        optimizer.step()
        train_loss += loss.item()
        train_acc += (torch.argmax(outputs, 1) == y_train).sum().item()
        count += len(y_train)

    train_loss /= len(train_loader)
    train_loss_lst.append(train_loss)

    train_acc /= count
    train_acc_lst.append(train_acc)

    val_loss = 0.0
    val_acc = 0.0
    count = 0
    model.eval()
    with torch.no_grad():
        for X_val, y_val in val_loader:
            X_val, y_val = X_val.to(device), y_val.to(device)
            outputs = model(X_val)
            loss = criterion(outputs, y_val)
            val_loss += loss.item()
            val_acc += (torch.argmax(outputs, 1) == y_val).sum().item()
            count += len(y_val)

    val_loss /= len(val_loader)
    val_loss_lst.append(val_loss)

    val_acc /= count
    val_acc_lst.append(val_acc)
    print(f"Epoch {epoch + 1} / {epochs}, train_loss: {train_loss: .4f}, train_acc:{train_acc: .4f}, validation loss: {val_loss: .4f}, val_acc: {val_acc: .4f}")
# Out:
# Epoch 1 / 100, train_loss:  0.7141, train_acc: 0.7868, validation loss:  0.4768, val_acc:  0.8308
# Epoch 2 / 100, train_loss:  0.4176, train_acc: 0.8504, validation loss:  0.4255, val_acc:  0.8488
# Epoch 3 / 100, train_loss:  0.3742, train_acc: 0.8648, validation loss:  0.3945, val_acc:  0.8570
# Epoch 4 / 100, train_loss:  0.3485, train_acc: 0.8742, validation loss:  0.3892, val_acc:  0.8623
# Epoch 5 / 100, train_loss:  0.3343, train_acc: 0.8777, validation loss:  0.3976, val_acc:  0.8602
# Epoch 6 / 100, train_loss:  0.3203, train_acc: 0.8834, validation loss:  0.3747, val_acc:  0.8680
# Epoch 7 / 100, train_loss:  0.3036, train_acc: 0.8881, validation loss:  0.3634, val_acc:  0.8693
# Epoch 8 / 100, train_loss:  0.2956, train_acc: 0.8909, validation loss:  0.3804, val_acc:  0.8650
# Epoch 9 / 100, train_loss:  0.2865, train_acc: 0.8944, validation loss:  0.3699, val_acc:  0.8743
# Epoch 10 / 100, train_loss:  0.2733, train_acc: 0.9001, validation loss:  0.3643, val_acc:  0.8700
# Epoch 11 / 100, train_loss:  0.2691, train_acc: 0.9006, validation loss:  0.3628, val_acc:  0.8778
# Epoch 12 / 100, train_loss:  0.2598, train_acc: 0.9034, validation loss:  0.3564, val_acc:  0.8753
# Epoch 13 / 100, train_loss:  0.2513, train_acc: 0.9078, validation loss:  0.3499, val_acc:  0.8783
# Epoch 14 / 100, train_loss:  0.2462, train_acc: 0.9087, validation loss:  0.3574, val_acc:  0.8790
# Epoch 15 / 100, train_loss:  0.2416, train_acc: 0.9102, validation loss:  0.3599, val_acc:  0.8732
# Epoch 16 / 100, train_loss:  0.2351, train_acc: 0.9124, validation loss:  0.3619, val_acc:  0.8745
# Epoch 17 / 100, train_loss:  0.2260, train_acc: 0.9161, validation loss:  0.3396, val_acc:  0.8867
# Epoch 18 / 100, train_loss:  0.2223, train_acc: 0.9171, validation loss:  0.3563, val_acc:  0.8793
# Epoch 19 / 100, train_loss:  0.2174, train_acc: 0.9195, validation loss:  0.3830, val_acc:  0.8725
# Epoch 20 / 100, train_loss:  0.2165, train_acc: 0.9182, validation loss:  0.3691, val_acc:  0.8805
# Epoch 21 / 100, train_loss:  0.2100, train_acc: 0.9211, validation loss:  0.3536, val_acc:  0.8840
# Epoch 22 / 100, train_loss:  0.2062, train_acc: 0.9228, validation loss:  0.3838, val_acc:  0.8737
# Epoch 23 / 100, train_loss:  0.1989, train_acc: 0.9261, validation loss:  0.3598, val_acc:  0.8782
# Epoch 24 / 100, train_loss:  0.1914, train_acc: 0.9284, validation loss:  0.3676, val_acc:  0.8798
# Epoch 25 / 100, train_loss:  0.1880, train_acc: 0.9302, validation loss:  0.3633, val_acc:  0.8805
# Epoch 26 / 100, train_loss:  0.1812, train_acc: 0.9333, validation loss:  0.3687, val_acc:  0.8762
# Epoch 27 / 100, train_loss:  0.1897, train_acc: 0.9280, validation loss:  0.3898, val_acc:  0.8767
# Epoch 28 / 100, train_loss:  0.1781, train_acc: 0.9334, validation loss:  0.3922, val_acc:  0.8738
# Epoch 29 / 100, train_loss:  0.1773, train_acc: 0.9337, validation loss:  0.3859, val_acc:  0.8733
# Epoch 30 / 100, train_loss:  0.1693, train_acc: 0.9380, validation loss:  0.3852, val_acc:  0.8773
# Epoch 31 / 100, train_loss:  0.1659, train_acc: 0.9378, validation loss:  0.3687, val_acc:  0.8835
# Epoch 32 / 100, train_loss:  0.1603, train_acc: 0.9394, validation loss:  0.3771, val_acc:  0.8788
# Epoch 33 / 100, train_loss:  0.1527, train_acc: 0.9433, validation loss:  0.3953, val_acc:  0.8807
# Epoch 34 / 100, train_loss:  0.1516, train_acc: 0.9440, validation loss:  0.4093, val_acc:  0.8792
# Epoch 35 / 100, train_loss:  0.1535, train_acc: 0.9430, validation loss:  0.3920, val_acc:  0.8805
# Epoch 36 / 100, train_loss:  0.1490, train_acc: 0.9441, validation loss:  0.4025, val_acc:  0.8827
# Epoch 37 / 100, train_loss:  0.1501, train_acc: 0.9417, validation loss:  0.3739, val_acc:  0.8848
# Epoch 38 / 100, train_loss:  0.1430, train_acc: 0.9467, validation loss:  0.3891, val_acc:  0.8850
# Epoch 39 / 100, train_loss:  0.1384, train_acc: 0.9482, validation loss:  0.3942, val_acc:  0.8775
# Epoch 40 / 100, train_loss:  0.1393, train_acc: 0.9487, validation loss:  0.3918, val_acc:  0.8822
# Epoch 41 / 100, train_loss:  0.1281, train_acc: 0.9520, validation loss:  0.4098, val_acc:  0.8813
# Epoch 42 / 100, train_loss:  0.1350, train_acc: 0.9493, validation loss:  0.4219, val_acc:  0.8765
# Epoch 43 / 100, train_loss:  0.1343, train_acc: 0.9486, validation loss:  0.4113, val_acc:  0.8787
# Epoch 44 / 100, train_loss:  0.1275, train_acc: 0.9524, validation loss:  0.4614, val_acc:  0.8665
# Epoch 45 / 100, train_loss:  0.1286, train_acc: 0.9523, validation loss:  0.4299, val_acc:  0.8802
# Epoch 46 / 100, train_loss:  0.1214, train_acc: 0.9548, validation loss:  0.4079, val_acc:  0.8820
# Epoch 47 / 100, train_loss:  0.1220, train_acc: 0.9532, validation loss:  0.4236, val_acc:  0.8742
# Epoch 48 / 100, train_loss:  0.1158, train_acc: 0.9563, validation loss:  0.4662, val_acc:  0.8785
# Epoch 49 / 100, train_loss:  0.1182, train_acc: 0.9553, validation loss:  0.4462, val_acc:  0.8782
# Epoch 50 / 100, train_loss:  0.1126, train_acc: 0.9588, validation loss:  0.4401, val_acc:  0.8787
# Epoch 51 / 100, train_loss:  0.1072, train_acc: 0.9591, validation loss:  0.4397, val_acc:  0.8777
# Epoch 52 / 100, train_loss:  0.1121, train_acc: 0.9574, validation loss:  0.4548, val_acc:  0.8795
# Epoch 53 / 100, train_loss:  0.1155, train_acc: 0.9568, validation loss:  0.4458, val_acc:  0.8798
# Epoch 54 / 100, train_loss:  0.1010, train_acc: 0.9616, validation loss:  0.4626, val_acc:  0.8773
# Epoch 55 / 100, train_loss:  0.1074, train_acc: 0.9606, validation loss:  0.5226, val_acc:  0.8613
# Epoch 56 / 100, train_loss:  0.0907, train_acc: 0.9677, validation loss:  0.4472, val_acc:  0.8828
# Epoch 57 / 100, train_loss:  0.0964, train_acc: 0.9633, validation loss:  0.4678, val_acc:  0.8758
# Epoch 58 / 100, train_loss:  0.1049, train_acc: 0.9608, validation loss:  0.4545, val_acc:  0.8828
# Epoch 59 / 100, train_loss:  0.0861, train_acc: 0.9676, validation loss:  0.4784, val_acc:  0.8807
# Epoch 60 / 100, train_loss:  0.0963, train_acc: 0.9644, validation loss:  0.4746, val_acc:  0.8803
# Epoch 61 / 100, train_loss:  0.0934, train_acc: 0.9649, validation loss:  0.5142, val_acc:  0.8737
# Epoch 62 / 100, train_loss:  0.0916, train_acc: 0.9659, validation loss:  0.4828, val_acc:  0.8797
# Epoch 63 / 100, train_loss:  0.0841, train_acc: 0.9691, validation loss:  0.4885, val_acc:  0.8807
# Epoch 64 / 100, train_loss:  0.0841, train_acc: 0.9681, validation loss:  0.5089, val_acc:  0.8775
# Epoch 65 / 100, train_loss:  0.0885, train_acc: 0.9672, validation loss:  0.5238, val_acc:  0.8785
# Epoch 66 / 100, train_loss:  0.0881, train_acc: 0.9676, validation loss:  0.5343, val_acc:  0.8743
# Epoch 67 / 100, train_loss:  0.0904, train_acc: 0.9658, validation loss:  0.5339, val_acc:  0.8767
# Epoch 68 / 100, train_loss:  0.0824, train_acc: 0.9696, validation loss:  0.4970, val_acc:  0.8848
# Epoch 69 / 100, train_loss:  0.0799, train_acc: 0.9696, validation loss:  0.4964, val_acc:  0.8850
# Epoch 70 / 100, train_loss:  0.0725, train_acc: 0.9731, validation loss:  0.5045, val_acc:  0.8757
# Epoch 71 / 100, train_loss:  0.0736, train_acc: 0.9727, validation loss:  0.5215, val_acc:  0.8768
# Epoch 72 / 100, train_loss:  0.0747, train_acc: 0.9720, validation loss:  0.5457, val_acc:  0.8762
# Epoch 73 / 100, train_loss:  0.0728, train_acc: 0.9743, validation loss:  0.5415, val_acc:  0.8728
# Epoch 74 / 100, train_loss:  0.0867, train_acc: 0.9673, validation loss:  0.5435, val_acc:  0.8670
# Epoch 75 / 100, train_loss:  0.0731, train_acc: 0.9727, validation loss:  0.4939, val_acc:  0.8817
# Epoch 76 / 100, train_loss:  0.0673, train_acc: 0.9756, validation loss:  0.5549, val_acc:  0.8795
# Epoch 77 / 100, train_loss:  0.0667, train_acc: 0.9756, validation loss:  0.5075, val_acc:  0.8835
# Epoch 78 / 100, train_loss:  0.0676, train_acc: 0.9745, validation loss:  0.5585, val_acc:  0.8753
# Epoch 79 / 100, train_loss:  0.0776, train_acc: 0.9709, validation loss:  0.5150, val_acc:  0.8827
# Epoch 80 / 100, train_loss:  0.0669, train_acc: 0.9749, validation loss:  0.5329, val_acc:  0.8800
# Epoch 81 / 100, train_loss:  0.0591, train_acc: 0.9781, validation loss:  0.5519, val_acc:  0.8755
# Epoch 82 / 100, train_loss:  0.0727, train_acc: 0.9730, validation loss:  0.5485, val_acc:  0.8783
# Epoch 83 / 100, train_loss:  0.0645, train_acc: 0.9754, validation loss:  0.5977, val_acc:  0.8740
# Epoch 84 / 100, train_loss:  0.0705, train_acc: 0.9731, validation loss:  0.5563, val_acc:  0.8803
# Epoch 85 / 100, train_loss:  0.0664, train_acc: 0.9751, validation loss:  0.5499, val_acc:  0.8798
# Epoch 86 / 100, train_loss:  0.0541, train_acc: 0.9801, validation loss:  0.5651, val_acc:  0.8787
# Epoch 87 / 100, train_loss:  0.0630, train_acc: 0.9762, validation loss:  0.5851, val_acc:  0.8723
# Epoch 88 / 100, train_loss:  0.0703, train_acc: 0.9729, validation loss:  0.5493, val_acc:  0.8798
# Epoch 89 / 100, train_loss:  0.0536, train_acc: 0.9798, validation loss:  0.5743, val_acc:  0.8775
# Epoch 90 / 100, train_loss:  0.0503, train_acc: 0.9811, validation loss:  0.6171, val_acc:  0.8785
# Epoch 91 / 100, train_loss:  0.0640, train_acc: 0.9767, validation loss:  0.5853, val_acc:  0.8773
# Epoch 92 / 100, train_loss:  0.0538, train_acc: 0.9803, validation loss:  0.5886, val_acc:  0.8782
# Epoch 93 / 100, train_loss:  0.0654, train_acc: 0.9761, validation loss:  0.5985, val_acc:  0.8760
# Epoch 94 / 100, train_loss:  0.0510, train_acc: 0.9808, validation loss:  0.6067, val_acc:  0.8788
# Epoch 95 / 100, train_loss:  0.0605, train_acc: 0.9773, validation loss:  0.5784, val_acc:  0.8800
# Epoch 96 / 100, train_loss:  0.0525, train_acc: 0.9806, validation loss:  0.5789, val_acc:  0.8782
# Epoch 97 / 100, train_loss:  0.0601, train_acc: 0.9781, validation loss:  0.5858, val_acc:  0.8742
# Epoch 98 / 100, train_loss:  0.0555, train_acc: 0.9788, validation loss:  0.5802, val_acc:  0.8750
# Epoch 99 / 100, train_loss:  0.0417, train_acc: 0.9850, validation loss:  0.6114, val_acc:  0.8827
# Epoch 100 / 100, train_loss:  0.0507, train_acc: 0.9813, validation loss:  0.6651, val_acc:  0.8698

# %% [markdown]
# ### Present results

# %%
# Present results
fig, ax = plt.subplots(2, 2, figsize=(12, 10))
ax[0, 0].plot(train_loss_lst, color='green')
ax[0, 0].set(xlabel='Epoch', ylabel='Loss')
ax[0, 0].set_title('Training Loss')

ax[0, 1].plot(val_loss_lst, color='orange')
ax[0, 1].set(xlabel='Epoch', ylabel='Loss')
ax[0, 1].set_title('Validation Loss')

ax[1, 0].plot(train_acc_lst, color='green')
ax[1, 0].set(xlabel='Epoch', ylabel='Accuracy')
ax[1, 0].set_title('Training Accuracy')

ax[1, 1].plot(val_acc_lst, color='orange')
ax[1, 1].set(xlabel='Epoch', ylabel='Accuracy')
ax[1, 1].set_title('Validation Accuracy')

plt.show()

# %% [markdown]
# ### Evaluation

# %%
# Evaluation
test_target = []
test_predict = []
model.eval()
with torch.no_grad():
    for X_test, y_test in test_loader:
        X_test, y_test = X_test.to(device), y_test.to(device)
        outputs = model(X_test)

        test_predict.append(outputs.cpu())
        test_target.append(y_test.cpu())

    test_predict = torch.cat(test_predict)
    test_target = torch.cat(test_target)
    test_acc = (torch.argmax(test_predict, 1) ==
                test_target).sum().item()/len(test_target)

    print(f"Accuracy: {test_acc}")
    print("============================================================")
# Out:
# Accuracy: 0.872
# ============================================================
