# %% [markdown]
# <a href="https://colab.research.google.com/github/lehuyphuong/Vanishing_gradient/blob/feature%2Fadd_solution_project_vanishing_gradient/Initial_model.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Import library

# %%
import random
import torch
import torch.optim as optim
import torchvision
import torchvision.transforms as transforms
from torch import nn
from torch.utils.data import Dataset, DataLoader, random_split
from torchvision.datasets import FashionMNIST
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ### Set up random seed

# %%
def set_seed(seed):
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False


SEED = 42
set_seed(SEED)

# %% [markdown]
# ### Download dataset

# %%
# download dataset
train_dataset = FashionMNIST('/content/drive/MyDrive/AIO_2024/Module_5/Week_4/data', train=True,
                             download=True,
                             transform=transforms.ToTensor())

test_dataset = FashionMNIST('/content/drive/MyDrive/AIO_2024/Module_5/Week_4/data', train=False,
                            download=True,
                            transform=transforms.ToTensor())

# %% [markdown]
# ### Split dataset

# %%
batch_size = 512


train_ratio = 0.9
train_size = int(len(train_dataset)*train_ratio)
val_size = len(train_dataset) - train_size

train_subnet, val_subnet = random_split(train_dataset, [train_size, val_size])
train_loader = DataLoader(train_subnet, batch_size=batch_size, shuffle=True)

val_loader = DataLoader(val_subnet, batch_size=batch_size, shuffle=False)
test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False)

print(f"Train size: {len(train_subnet)}")
print(f"Val size: {len(val_subnet)}")
print(f"Test size: {len(test_dataset)}")
# Out:
# Train size: 54000
# Val size: 6000
# Test size: 10000

# %% [markdown]
# ### Define model

# %%
device = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')
class MLP(nn.Module):
    def __init__(self, input_dims, hidden_dims, output_dims):
        super().__init__()
        self.layer1 = nn.Linear(input_dims, hidden_dims)
        self.layer2 = nn.Linear(hidden_dims, hidden_dims)
        self.layer3 = nn.Linear(hidden_dims, hidden_dims)
        self.layer4 = nn.Linear(hidden_dims, hidden_dims)
        self.layer5 = nn.Linear(hidden_dims, hidden_dims)
        self.layer6 = nn.Linear(hidden_dims, hidden_dims)
        self.layer7 = nn.Linear(hidden_dims, hidden_dims)
        self.output = nn.Linear(hidden_dims, output_dims)

    def forward(self, x):
        x = nn.Flatten()(x)
        x = self.layer1(x)
        x = nn.Sigmoid()(x)
        x = self.layer2(x)
        x = nn.Sigmoid()(x)
        x = self.layer3(x)
        x = nn.Sigmoid()(x)
        x = self.layer4(x)
        x = nn.Sigmoid()(x)
        x = self.layer5(x)
        x = nn.Sigmoid()(x)
        x = self.layer6(x)
        x = nn.Sigmoid()(x)
        x = self.layer7(x)
        x = nn.Sigmoid()(x)
        out = self.output(x)

        return out


input_dims = 784
hidden_dims = 128
output_dims = 10
lr = 1e-2
model = MLP(input_dims=input_dims, hidden_dims=hidden_dims,
            output_dims=output_dims).to(device)

criterion = nn.CrossEntropyLoss()
optimizer = optim.SGD(model.parameters(), lr=lr)

# %% [markdown]
# ### Train model

# %%
# train model
epochs = 100
train_loss_lst = []
train_acc_lst = []
val_loss_lst = []
val_acc_lst = []
for epoch in range(epochs):
    train_loss = 0.0
    train_acc = 0.0
    count = 0

    model.train()
    for X_train, y_train in train_loader:
        X_train, y_train = X_train.to(device), y_train.to(device)
        optimizer.zero_grad()
        outputs = model(X_train)
        loss = criterion(outputs, y_train)
        loss.backward()
        optimizer.step()
        train_loss += loss.item()
        train_acc += (torch.argmax(outputs, 1) == y_train).sum().item()
        count += len(y_train)

    train_loss /= len(train_loader)
    train_loss_lst.append(train_loss)

    train_acc /= count
    train_acc_lst.append(train_acc)

    val_loss = 0.0
    val_acc = 0.0
    count = 0
    model.eval()
    with torch.no_grad():
        for X_val, y_val in val_loader:
            X_val, y_val = X_val.to(device), y_val.to(device)
            outputs = model(X_val)
            loss = criterion(outputs, y_val)
            val_loss += loss.item()
            val_acc += (torch.argmax(outputs, 1) == y_val).sum().item()
            count += len(y_val)

    val_loss /= len(val_loader)
    val_loss_lst.append(val_loss)

    val_acc /= count
    val_acc_lst.append(val_acc)
    print(f"Epoch {epoch + 1} / {epochs}, train_loss: {train_loss: .4f}, train_acc:{train_acc: .4f}, validation loss: {val_loss: .4f}, val_acc: {val_acc: .4f}")
# Out:
# Epoch 1 / 100, train_loss:  2.3073, train_acc: 0.0996, validation loss:  2.3034, val_acc:  0.0937
# Epoch 2 / 100, train_loss:  2.3028, train_acc: 0.0977, validation loss:  2.3030, val_acc:  0.1020
# Epoch 3 / 100, train_loss:  2.3028, train_acc: 0.0996, validation loss:  2.3030, val_acc:  0.1022
# Epoch 4 / 100, train_loss:  2.3028, train_acc: 0.0992, validation loss:  2.3028, val_acc:  0.0937
# Epoch 5 / 100, train_loss:  2.3027, train_acc: 0.1016, validation loss:  2.3028, val_acc:  0.1012
# Epoch 6 / 100, train_loss:  2.3028, train_acc: 0.0977, validation loss:  2.3030, val_acc:  0.0895
# Epoch 7 / 100, train_loss:  2.3028, train_acc: 0.0979, validation loss:  2.3029, val_acc:  0.0937
# Epoch 8 / 100, train_loss:  2.3028, train_acc: 0.0982, validation loss:  2.3028, val_acc:  0.1022
# Epoch 9 / 100, train_loss:  2.3028, train_acc: 0.1012, validation loss:  2.3028, val_acc:  0.1012
# Epoch 10 / 100, train_loss:  2.3028, train_acc: 0.1004, validation loss:  2.3026, val_acc:  0.1097
# Epoch 11 / 100, train_loss:  2.3028, train_acc: 0.0988, validation loss:  2.3030, val_acc:  0.0937
# Epoch 12 / 100, train_loss:  2.3028, train_acc: 0.0975, validation loss:  2.3034, val_acc:  0.0937
# Epoch 13 / 100, train_loss:  2.3028, train_acc: 0.0999, validation loss:  2.3029, val_acc:  0.0937
# Epoch 14 / 100, train_loss:  2.3027, train_acc: 0.1005, validation loss:  2.3034, val_acc:  0.0895
# Epoch 15 / 100, train_loss:  2.3027, train_acc: 0.1001, validation loss:  2.3032, val_acc:  0.0937
# Epoch 16 / 100, train_loss:  2.3028, train_acc: 0.0999, validation loss:  2.3032, val_acc:  0.1012
# Epoch 17 / 100, train_loss:  2.3028, train_acc: 0.0977, validation loss:  2.3029, val_acc:  0.1003
# Epoch 18 / 100, train_loss:  2.3028, train_acc: 0.0982, validation loss:  2.3025, val_acc:  0.1012
# Epoch 19 / 100, train_loss:  2.3028, train_acc: 0.0974, validation loss:  2.3029, val_acc:  0.0937
# Epoch 20 / 100, train_loss:  2.3028, train_acc: 0.0993, validation loss:  2.3028, val_acc:  0.0937
# Epoch 21 / 100, train_loss:  2.3028, train_acc: 0.0999, validation loss:  2.3026, val_acc:  0.0997
# Epoch 22 / 100, train_loss:  2.3028, train_acc: 0.0973, validation loss:  2.3031, val_acc:  0.1022
# Epoch 23 / 100, train_loss:  2.3028, train_acc: 0.1003, validation loss:  2.3029, val_acc:  0.0895
# Epoch 24 / 100, train_loss:  2.3028, train_acc: 0.0988, validation loss:  2.3029, val_acc:  0.0997
# Epoch 25 / 100, train_loss:  2.3027, train_acc: 0.1004, validation loss:  2.3032, val_acc:  0.1022
# Epoch 26 / 100, train_loss:  2.3028, train_acc: 0.0977, validation loss:  2.3032, val_acc:  0.0895
# Epoch 27 / 100, train_loss:  2.3028, train_acc: 0.0975, validation loss:  2.3028, val_acc:  0.1018
# Epoch 28 / 100, train_loss:  2.3028, train_acc: 0.0997, validation loss:  2.3030, val_acc:  0.1000
# Epoch 29 / 100, train_loss:  2.3028, train_acc: 0.0976, validation loss:  2.3030, val_acc:  0.1012
# Epoch 30 / 100, train_loss:  2.3028, train_acc: 0.0992, validation loss:  2.3029, val_acc:  0.1020
# Epoch 31 / 100, train_loss:  2.3028, train_acc: 0.0985, validation loss:  2.3033, val_acc:  0.0895
# Epoch 32 / 100, train_loss:  2.3028, train_acc: 0.1000, validation loss:  2.3029, val_acc:  0.0895
# Epoch 33 / 100, train_loss:  2.3027, train_acc: 0.0997, validation loss:  2.3027, val_acc:  0.1000
# Epoch 34 / 100, train_loss:  2.3027, train_acc: 0.0984, validation loss:  2.3026, val_acc:  0.1022
# Epoch 35 / 100, train_loss:  2.3028, train_acc: 0.0973, validation loss:  2.3026, val_acc:  0.1022
# Epoch 36 / 100, train_loss:  2.3027, train_acc: 0.0987, validation loss:  2.3028, val_acc:  0.1012
# Epoch 37 / 100, train_loss:  2.3028, train_acc: 0.0985, validation loss:  2.3030, val_acc:  0.0997
# Epoch 38 / 100, train_loss:  2.3028, train_acc: 0.0996, validation loss:  2.3031, val_acc:  0.0895
# Epoch 39 / 100, train_loss:  2.3028, train_acc: 0.0987, validation loss:  2.3028, val_acc:  0.1003
# Epoch 40 / 100, train_loss:  2.3028, train_acc: 0.0991, validation loss:  2.3033, val_acc:  0.1000
# Epoch 41 / 100, train_loss:  2.3028, train_acc: 0.0990, validation loss:  2.3031, val_acc:  0.1012
# Epoch 42 / 100, train_loss:  2.3027, train_acc: 0.1005, validation loss:  2.3030, val_acc:  0.0895
# Epoch 43 / 100, train_loss:  2.3028, train_acc: 0.0976, validation loss:  2.3030, val_acc:  0.0895
# Epoch 44 / 100, train_loss:  2.3028, train_acc: 0.1007, validation loss:  2.3030, val_acc:  0.0997
# Epoch 45 / 100, train_loss:  2.3028, train_acc: 0.1004, validation loss:  2.3030, val_acc:  0.0937
# Epoch 46 / 100, train_loss:  2.3028, train_acc: 0.0995, validation loss:  2.3028, val_acc:  0.1003
# Epoch 47 / 100, train_loss:  2.3028, train_acc: 0.0990, validation loss:  2.3032, val_acc:  0.0895
# Epoch 48 / 100, train_loss:  2.3028, train_acc: 0.0983, validation loss:  2.3027, val_acc:  0.1020
# Epoch 49 / 100, train_loss:  2.3028, train_acc: 0.0977, validation loss:  2.3028, val_acc:  0.1012
# Epoch 50 / 100, train_loss:  2.3028, train_acc: 0.0986, validation loss:  2.3027, val_acc:  0.1018
# Epoch 51 / 100, train_loss:  2.3028, train_acc: 0.0988, validation loss:  2.3026, val_acc:  0.0997
# Epoch 52 / 100, train_loss:  2.3028, train_acc: 0.0989, validation loss:  2.3030, val_acc:  0.0895
# Epoch 53 / 100, train_loss:  2.3028, train_acc: 0.0996, validation loss:  2.3028, val_acc:  0.0937
# Epoch 54 / 100, train_loss:  2.3028, train_acc: 0.0990, validation loss:  2.3030, val_acc:  0.0895
# Epoch 55 / 100, train_loss:  2.3028, train_acc: 0.0985, validation loss:  2.3028, val_acc:  0.1022
# Epoch 56 / 100, train_loss:  2.3027, train_acc: 0.0975, validation loss:  2.3032, val_acc:  0.1020
# Epoch 57 / 100, train_loss:  2.3028, train_acc: 0.0998, validation loss:  2.3032, val_acc:  0.0895
# Epoch 58 / 100, train_loss:  2.3027, train_acc: 0.1023, validation loss:  2.3031, val_acc:  0.0937
# Epoch 59 / 100, train_loss:  2.3028, train_acc: 0.0981, validation loss:  2.3027, val_acc:  0.1018
# Epoch 60 / 100, train_loss:  2.3028, train_acc: 0.0977, validation loss:  2.3034, val_acc:  0.0895
# Epoch 61 / 100, train_loss:  2.3028, train_acc: 0.0974, validation loss:  2.3031, val_acc:  0.0895
# Epoch 62 / 100, train_loss:  2.3028, train_acc: 0.0980, validation loss:  2.3027, val_acc:  0.1003
# Epoch 63 / 100, train_loss:  2.3028, train_acc: 0.0999, validation loss:  2.3030, val_acc:  0.1000
# Epoch 64 / 100, train_loss:  2.3028, train_acc: 0.0992, validation loss:  2.3028, val_acc:  0.0997
# Epoch 65 / 100, train_loss:  2.3028, train_acc: 0.0982, validation loss:  2.3028, val_acc:  0.0937
# Epoch 66 / 100, train_loss:  2.3027, train_acc: 0.1010, validation loss:  2.3031, val_acc:  0.0895
# Epoch 67 / 100, train_loss:  2.3028, train_acc: 0.0992, validation loss:  2.3028, val_acc:  0.0997
# Epoch 68 / 100, train_loss:  2.3028, train_acc: 0.0985, validation loss:  2.3028, val_acc:  0.0895
# Epoch 69 / 100, train_loss:  2.3028, train_acc: 0.0991, validation loss:  2.3028, val_acc:  0.0895
# Epoch 70 / 100, train_loss:  2.3028, train_acc: 0.0953, validation loss:  2.3029, val_acc:  0.1020
# Epoch 71 / 100, train_loss:  2.3028, train_acc: 0.1005, validation loss:  2.3030, val_acc:  0.0937
# Epoch 72 / 100, train_loss:  2.3027, train_acc: 0.1029, validation loss:  2.3027, val_acc:  0.1000
# Epoch 73 / 100, train_loss:  2.3027, train_acc: 0.1011, validation loss:  2.3028, val_acc:  0.0895
# Epoch 74 / 100, train_loss:  2.3028, train_acc: 0.0993, validation loss:  2.3029, val_acc:  0.1012
# Epoch 75 / 100, train_loss:  2.3028, train_acc: 0.0995, validation loss:  2.3031, val_acc:  0.0937
# Epoch 76 / 100, train_loss:  2.3028, train_acc: 0.0978, validation loss:  2.3027, val_acc:  0.1000
# Epoch 77 / 100, train_loss:  2.3028, train_acc: 0.1009, validation loss:  2.3030, val_acc:  0.0895
# Epoch 78 / 100, train_loss:  2.3028, train_acc: 0.1000, validation loss:  2.3033, val_acc:  0.0895
# Epoch 79 / 100, train_loss:  2.3028, train_acc: 0.1000, validation loss:  2.3031, val_acc:  0.0937
# Epoch 80 / 100, train_loss:  2.3028, train_acc: 0.0999, validation loss:  2.3030, val_acc:  0.0895
# Epoch 81 / 100, train_loss:  2.3028, train_acc: 0.0983, validation loss:  2.3032, val_acc:  0.0895
# Epoch 82 / 100, train_loss:  2.3028, train_acc: 0.1002, validation loss:  2.3028, val_acc:  0.0937
# Epoch 83 / 100, train_loss:  2.3028, train_acc: 0.0998, validation loss:  2.3033, val_acc:  0.1018
# Epoch 84 / 100, train_loss:  2.3028, train_acc: 0.1007, validation loss:  2.3029, val_acc:  0.1022
# Epoch 85 / 100, train_loss:  2.3028, train_acc: 0.0989, validation loss:  2.3028, val_acc:  0.0937
# Epoch 86 / 100, train_loss:  2.3028, train_acc: 0.0992, validation loss:  2.3032, val_acc:  0.0895
# Epoch 87 / 100, train_loss:  2.3028, train_acc: 0.0997, validation loss:  2.3028, val_acc:  0.0937
# Epoch 88 / 100, train_loss:  2.3028, train_acc: 0.0971, validation loss:  2.3032, val_acc:  0.0895
# Epoch 89 / 100, train_loss:  2.3028, train_acc: 0.0989, validation loss:  2.3030, val_acc:  0.1018
# Epoch 90 / 100, train_loss:  2.3028, train_acc: 0.0986, validation loss:  2.3032, val_acc:  0.0895
# Epoch 91 / 100, train_loss:  2.3028, train_acc: 0.0996, validation loss:  2.3031, val_acc:  0.0937
# Epoch 92 / 100, train_loss:  2.3027, train_acc: 0.0996, validation loss:  2.3027, val_acc:  0.0997
# Epoch 93 / 100, train_loss:  2.3028, train_acc: 0.0983, validation loss:  2.3031, val_acc:  0.0895
# Epoch 94 / 100, train_loss:  2.3028, train_acc: 0.0961, validation loss:  2.3030, val_acc:  0.0895
# Epoch 95 / 100, train_loss:  2.3027, train_acc: 0.0996, validation loss:  2.3027, val_acc:  0.1003
# Epoch 96 / 100, train_loss:  2.3028, train_acc: 0.0982, validation loss:  2.3029, val_acc:  0.0937
# Epoch 97 / 100, train_loss:  2.3028, train_acc: 0.0990, validation loss:  2.3030, val_acc:  0.0895
# Epoch 98 / 100, train_loss:  2.3028, train_acc: 0.0986, validation loss:  2.3034, val_acc:  0.0937
# Epoch 99 / 100, train_loss:  2.3027, train_acc: 0.1009, validation loss:  2.3027, val_acc:  0.1000
# Epoch 100 / 100, train_loss:  2.3028, train_acc: 0.0959, validation loss:  2.3028, val_acc:  0.0895

# %% [markdown]
# ### Present results

# %%
# Present results
fig, ax = plt.subplots(2, 2, figsize=(12, 10))
ax[0, 0].plot(train_loss_lst, color='green')
ax[0, 0].set(xlabel='Epoch', ylabel='Loss')
ax[0, 0].set_title('Training Loss')

ax[0, 1].plot(val_loss_lst, color='orange')
ax[0, 1].set(xlabel='Epoch', ylabel='Loss')
ax[0, 1].set_title('Validation Loss')

ax[1, 0].plot(train_acc_lst, color='green')
ax[1, 0].set(xlabel='Epoch', ylabel='Accuracy')
ax[1, 0].set_title('Training Accuracy')

ax[1, 1].plot(val_acc_lst, color='orange')
ax[1, 1].set(xlabel='Epoch', ylabel='Accuracy')
ax[1, 1].set_title('Validation Accuracy')

plt.show()

# %% [markdown]
# ### Evaluation

# %%
# Evaluation
test_target = []
test_predict = []
model.eval()
with torch.no_grad():
    for X_test, y_test in test_loader:
        X_test, y_test = X_test.to(device), y_test.to(device)
        outputs = model(X_test)

        test_predict.append(outputs.cpu())
        test_target.append(y_test.cpu())

    test_predict = torch.cat(test_predict)
    test_target = torch.cat(test_target)
    test_acc = (torch.argmax(test_predict, 1) ==
                test_target).sum().item()/len(test_target)

    print(f"Accuracy: {test_acc}")
    print("============================================================")
# Out:
# Accuracy: 0.1
# ============================================================
