# %% [markdown]
# <a href="https://colab.research.google.com/github/lehuyphuong/Vanishing_gradient/blob/feature%2Fadd_solution_project_vanishing_gradient/model_updated_by_normalization_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Import library

# %%
import random
import torch
import torch.optim as optim
import torchvision
import torchvision.transforms as transforms
from torch import nn
from torch.utils.data import Dataset, DataLoader, random_split
from torchvision.datasets import FashionMNIST
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ### Set up random seed

# %%
def set_seed(seed):
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False


SEED = 42
set_seed(SEED)

# %% [markdown]
# ### Download dataset

# %%
# download dataset
train_dataset = FashionMNIST('/content/drive/MyDrive/AIO_2024/Module_5/Week_4/data', train=True,
                             download=True,
                             transform=transforms.ToTensor())

test_dataset = FashionMNIST('/content/drive/MyDrive/AIO_2024/Module_5/Week_4/data', train=False,
                            download=True,
                            transform=transforms.ToTensor())

# %% [markdown]
# ### Split dataset

# %%
batch_size = 512


train_ratio = 0.9
train_size = int(len(train_dataset)*train_ratio)
val_size = len(train_dataset) - train_size

train_subnet, val_subnet = random_split(train_dataset, [train_size, val_size])
train_loader = DataLoader(train_subnet, batch_size=batch_size, shuffle=True)

val_loader = DataLoader(val_subnet, batch_size=batch_size, shuffle=False)
test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False)

print(f"Train size: {len(train_subnet)}")
print(f"Val size: {len(val_subnet)}")
print(f"Test size: {len(test_dataset)}")
# Out:
# Train size: 54000
# Val size: 6000
# Test size: 10000

# %% [markdown]
# ### Define model

# %%
device = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')
class MyNormalization(nn.Module):
  def __init__(self):
    super().__init__()
  def forward(self, x):
    mean = torch.mean(x)
    std = torch.std(x)
    return (x - mean) / std

class MLP(nn.Module):
    def __init__(self, input_dims, hidden_dims, output_dims):
        super().__init__()
        self.layer1 = nn.Linear(input_dims, hidden_dims)
        self.layer2 = nn.Linear(hidden_dims, hidden_dims)
        self.layer3 = nn.Linear(hidden_dims, hidden_dims)
        self.layer4 = nn.Linear(hidden_dims, hidden_dims)
        self.layer5 = nn.Linear(hidden_dims, hidden_dims)
        self.layer6 = nn.Linear(hidden_dims, hidden_dims)
        self.layer7 = nn.Linear(hidden_dims, hidden_dims)
        self.output = nn.Linear(hidden_dims, output_dims)

        for module in self.modules():
          if isinstance(module, nn.Linear):
            nn.init.normal_(module.weight, mean=0.0, std=1.0)
            nn.init.constant_(module.bias, 0.0)
        self.custom_normalization = MyNormalization()

    def forward(self, x):
        x = nn.Flatten()(x)
        x = self.layer1(x)
        x = self.custom_normalization(x)
        x = nn.Sigmoid()(x)
        x = self.layer2(x)
        x = self.custom_normalization(x)
        x = nn.Sigmoid()(x)
        x = self.layer3(x)
        x = self.custom_normalization(x)
        x = nn.Sigmoid()(x)
        x = self.layer4(x)
        x = self.custom_normalization(x)
        x = nn.Sigmoid()(x)
        x = self.layer5(x)
        x = self.custom_normalization(x)
        x = nn.Sigmoid()(x)
        x = self.layer6(x)
        x = self.custom_normalization(x)
        x = nn.Sigmoid()(x)
        x = self.layer7(x)
        x = self.custom_normalization(x)
        x = nn.Sigmoid()(x)
        out = self.output(x)

        return out


input_dims = 784
hidden_dims = 128
output_dims = 10
lr = 1e-2
model = MLP(input_dims=input_dims, hidden_dims=hidden_dims,
            output_dims=output_dims).to(device)

criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=lr)

# %% [markdown]
# ### Train model

# %%
# train model
epochs = 100
train_loss_lst = []
train_acc_lst = []
val_loss_lst = []
val_acc_lst = []
for epoch in range(epochs):
    train_loss = 0.0
    train_acc = 0.0
    count = 0

    model.train()
    for X_train, y_train in train_loader:
        X_train, y_train = X_train.to(device), y_train.to(device)
        optimizer.zero_grad()
        outputs = model(X_train)
        loss = criterion(outputs, y_train)
        loss.backward()
        optimizer.step()
        train_loss += loss.item()
        train_acc += (torch.argmax(outputs, 1) == y_train).sum().item()
        count += len(y_train)

    train_loss /= len(train_loader)
    train_loss_lst.append(train_loss)

    train_acc /= count
    train_acc_lst.append(train_acc)

    val_loss = 0.0
    val_acc = 0.0
    count = 0
    model.eval()
    with torch.no_grad():
        for X_val, y_val in val_loader:
            X_val, y_val = X_val.to(device), y_val.to(device)
            outputs = model(X_val)
            loss = criterion(outputs, y_val)
            val_loss += loss.item()
            val_acc += (torch.argmax(outputs, 1) == y_val).sum().item()
            count += len(y_val)

    val_loss /= len(val_loader)
    val_loss_lst.append(val_loss)

    val_acc /= count
    val_acc_lst.append(val_acc)
    print(f"Epoch {epoch + 1} / {epochs}, train_loss: {train_loss: .4f}, train_acc:{train_acc: .4f}, validation loss: {val_loss: .4f}, val_acc: {val_acc: .4f}")
# Out:
# Epoch 1 / 100, train_loss:  2.1434, train_acc: 0.2885, validation loss:  0.6840, val_acc:  0.7573
# Epoch 2 / 100, train_loss:  0.5396, train_acc: 0.8052, validation loss:  0.5081, val_acc:  0.8232
# Epoch 3 / 100, train_loss:  0.4485, train_acc: 0.8375, validation loss:  0.4971, val_acc:  0.8278
# Epoch 4 / 100, train_loss:  0.4378, train_acc: 0.8409, validation loss:  0.4540, val_acc:  0.8413
# Epoch 5 / 100, train_loss:  0.4114, train_acc: 0.8497, validation loss:  0.4254, val_acc:  0.8515
# Epoch 6 / 100, train_loss:  0.4034, train_acc: 0.8542, validation loss:  0.4151, val_acc:  0.8527
# Epoch 7 / 100, train_loss:  0.3856, train_acc: 0.8595, validation loss:  0.4000, val_acc:  0.8623
# Epoch 8 / 100, train_loss:  0.3749, train_acc: 0.8633, validation loss:  0.4147, val_acc:  0.8553
# Epoch 9 / 100, train_loss:  0.3651, train_acc: 0.8678, validation loss:  0.4237, val_acc:  0.8595
# Epoch 10 / 100, train_loss:  0.3524, train_acc: 0.8723, validation loss:  0.3745, val_acc:  0.8672
# Epoch 11 / 100, train_loss:  0.3512, train_acc: 0.8728, validation loss:  0.3909, val_acc:  0.8580
# Epoch 12 / 100, train_loss:  0.3441, train_acc: 0.8756, validation loss:  0.3819, val_acc:  0.8638
# Epoch 13 / 100, train_loss:  0.3543, train_acc: 0.8701, validation loss:  0.4024, val_acc:  0.8575
# Epoch 14 / 100, train_loss:  0.3435, train_acc: 0.8746, validation loss:  0.3881, val_acc:  0.8627
# Epoch 15 / 100, train_loss:  0.3269, train_acc: 0.8803, validation loss:  0.4340, val_acc:  0.8462
# Epoch 16 / 100, train_loss:  0.3312, train_acc: 0.8780, validation loss:  0.4131, val_acc:  0.8452
# Epoch 17 / 100, train_loss:  0.3291, train_acc: 0.8783, validation loss:  0.4108, val_acc:  0.8500
# Epoch 18 / 100, train_loss:  0.3262, train_acc: 0.8792, validation loss:  0.4106, val_acc:  0.8512
# Epoch 19 / 100, train_loss:  0.3190, train_acc: 0.8824, validation loss:  0.3959, val_acc:  0.8600
# Epoch 20 / 100, train_loss:  0.3100, train_acc: 0.8849, validation loss:  0.3777, val_acc:  0.8647
# Epoch 21 / 100, train_loss:  0.3161, train_acc: 0.8840, validation loss:  0.3658, val_acc:  0.8687
# Epoch 22 / 100, train_loss:  0.3005, train_acc: 0.8891, validation loss:  0.4044, val_acc:  0.8595
# Epoch 23 / 100, train_loss:  0.2987, train_acc: 0.8902, validation loss:  0.3672, val_acc:  0.8712
# Epoch 24 / 100, train_loss:  0.2977, train_acc: 0.8915, validation loss:  0.3878, val_acc:  0.8650
# Epoch 25 / 100, train_loss:  0.2902, train_acc: 0.8936, validation loss:  0.3694, val_acc:  0.8705
# Epoch 26 / 100, train_loss:  0.2975, train_acc: 0.8915, validation loss:  0.3749, val_acc:  0.8670
# Epoch 27 / 100, train_loss:  0.2893, train_acc: 0.8941, validation loss:  0.3695, val_acc:  0.8695
# Epoch 28 / 100, train_loss:  0.2867, train_acc: 0.8951, validation loss:  0.3702, val_acc:  0.8693
# Epoch 29 / 100, train_loss:  0.2754, train_acc: 0.8978, validation loss:  0.3626, val_acc:  0.8758
# Epoch 30 / 100, train_loss:  0.2801, train_acc: 0.8972, validation loss:  0.4045, val_acc:  0.8570
# Epoch 31 / 100, train_loss:  0.2747, train_acc: 0.8977, validation loss:  0.3935, val_acc:  0.8648
# Epoch 32 / 100, train_loss:  0.2699, train_acc: 0.9000, validation loss:  0.3826, val_acc:  0.8665
# Epoch 33 / 100, train_loss:  0.2714, train_acc: 0.9001, validation loss:  0.3840, val_acc:  0.8667
# Epoch 34 / 100, train_loss:  0.2691, train_acc: 0.9007, validation loss:  0.3819, val_acc:  0.8702
# Epoch 35 / 100, train_loss:  0.2646, train_acc: 0.9025, validation loss:  0.3524, val_acc:  0.8783
# Epoch 36 / 100, train_loss:  0.2629, train_acc: 0.9032, validation loss:  0.3709, val_acc:  0.8702
# Epoch 37 / 100, train_loss:  0.2621, train_acc: 0.9029, validation loss:  0.3517, val_acc:  0.8782
# Epoch 38 / 100, train_loss:  0.2532, train_acc: 0.9052, validation loss:  0.3724, val_acc:  0.8718
# Epoch 39 / 100, train_loss:  0.2509, train_acc: 0.9065, validation loss:  0.3680, val_acc:  0.8698
# Epoch 40 / 100, train_loss:  0.2561, train_acc: 0.9053, validation loss:  0.3970, val_acc:  0.8672
# Epoch 41 / 100, train_loss:  0.2443, train_acc: 0.9096, validation loss:  0.3748, val_acc:  0.8675
# Epoch 42 / 100, train_loss:  0.2587, train_acc: 0.9046, validation loss:  0.3453, val_acc:  0.8815
# Epoch 43 / 100, train_loss:  0.2396, train_acc: 0.9109, validation loss:  0.3487, val_acc:  0.8763
# Epoch 44 / 100, train_loss:  0.2394, train_acc: 0.9111, validation loss:  0.3645, val_acc:  0.8758
# Epoch 45 / 100, train_loss:  0.2497, train_acc: 0.9068, validation loss:  0.3772, val_acc:  0.8712
# Epoch 46 / 100, train_loss:  0.2337, train_acc: 0.9145, validation loss:  0.3463, val_acc:  0.8800
# Epoch 47 / 100, train_loss:  0.2312, train_acc: 0.9147, validation loss:  0.3588, val_acc:  0.8752
# Epoch 48 / 100, train_loss:  0.2306, train_acc: 0.9149, validation loss:  0.3424, val_acc:  0.8800
# Epoch 49 / 100, train_loss:  0.2308, train_acc: 0.9145, validation loss:  0.3558, val_acc:  0.8797
# Epoch 50 / 100, train_loss:  0.2372, train_acc: 0.9126, validation loss:  0.3793, val_acc:  0.8762
# Epoch 51 / 100, train_loss:  0.2203, train_acc: 0.9176, validation loss:  0.3838, val_acc:  0.8670
# Epoch 52 / 100, train_loss:  0.2281, train_acc: 0.9158, validation loss:  0.3823, val_acc:  0.8775
# Epoch 53 / 100, train_loss:  0.2254, train_acc: 0.9163, validation loss:  0.3525, val_acc:  0.8817
# Epoch 54 / 100, train_loss:  0.2086, train_acc: 0.9234, validation loss:  0.3562, val_acc:  0.8845
# Epoch 55 / 100, train_loss:  0.2198, train_acc: 0.9189, validation loss:  0.3728, val_acc:  0.8722
# Epoch 56 / 100, train_loss:  0.2358, train_acc: 0.9130, validation loss:  0.3868, val_acc:  0.8693
# Epoch 57 / 100, train_loss:  0.2150, train_acc: 0.9197, validation loss:  0.4043, val_acc:  0.8615
# Epoch 58 / 100, train_loss:  0.2184, train_acc: 0.9201, validation loss:  0.3684, val_acc:  0.8785
# Epoch 59 / 100, train_loss:  0.2126, train_acc: 0.9199, validation loss:  0.3648, val_acc:  0.8767
# Epoch 60 / 100, train_loss:  0.2111, train_acc: 0.9209, validation loss:  0.3938, val_acc:  0.8750
# Epoch 61 / 100, train_loss:  0.2121, train_acc: 0.9213, validation loss:  0.3811, val_acc:  0.8702
# Epoch 62 / 100, train_loss:  0.2152, train_acc: 0.9195, validation loss:  0.4485, val_acc:  0.8593
# Epoch 63 / 100, train_loss:  0.2133, train_acc: 0.9201, validation loss:  0.4156, val_acc:  0.8673
# Epoch 64 / 100, train_loss:  0.2029, train_acc: 0.9247, validation loss:  0.3758, val_acc:  0.8735
# Epoch 65 / 100, train_loss:  0.2091, train_acc: 0.9226, validation loss:  0.3687, val_acc:  0.8783
# Epoch 66 / 100, train_loss:  0.1903, train_acc: 0.9298, validation loss:  0.3718, val_acc:  0.8797
# Epoch 67 / 100, train_loss:  0.2070, train_acc: 0.9233, validation loss:  0.3806, val_acc:  0.8777
# Epoch 68 / 100, train_loss:  0.1937, train_acc: 0.9277, validation loss:  0.3938, val_acc:  0.8750
# Epoch 69 / 100, train_loss:  0.2093, train_acc: 0.9227, validation loss:  0.3815, val_acc:  0.8732
# Epoch 70 / 100, train_loss:  0.1857, train_acc: 0.9302, validation loss:  0.3867, val_acc:  0.8790
# Epoch 71 / 100, train_loss:  0.1904, train_acc: 0.9302, validation loss:  0.4092, val_acc:  0.8710
# Epoch 72 / 100, train_loss:  0.1914, train_acc: 0.9286, validation loss:  0.3743, val_acc:  0.8813
# Epoch 73 / 100, train_loss:  0.1852, train_acc: 0.9304, validation loss:  0.3862, val_acc:  0.8792
# Epoch 74 / 100, train_loss:  0.1892, train_acc: 0.9294, validation loss:  0.3889, val_acc:  0.8647
# Epoch 75 / 100, train_loss:  0.1902, train_acc: 0.9294, validation loss:  0.4013, val_acc:  0.8760
# Epoch 76 / 100, train_loss:  0.1953, train_acc: 0.9272, validation loss:  0.3485, val_acc:  0.8798
# Epoch 77 / 100, train_loss:  0.1831, train_acc: 0.9323, validation loss:  0.4230, val_acc:  0.8690
# Epoch 78 / 100, train_loss:  0.1839, train_acc: 0.9313, validation loss:  0.4432, val_acc:  0.8717
# Epoch 79 / 100, train_loss:  0.1747, train_acc: 0.9354, validation loss:  0.4858, val_acc:  0.8637
# Epoch 80 / 100, train_loss:  0.1783, train_acc: 0.9342, validation loss:  0.3943, val_acc:  0.8725
# Epoch 81 / 100, train_loss:  0.1768, train_acc: 0.9337, validation loss:  0.3780, val_acc:  0.8800
# Epoch 82 / 100, train_loss:  0.1639, train_acc: 0.9395, validation loss:  0.4310, val_acc:  0.8683
# Epoch 83 / 100, train_loss:  0.1746, train_acc: 0.9343, validation loss:  0.4565, val_acc:  0.8600
# Epoch 84 / 100, train_loss:  0.1725, train_acc: 0.9354, validation loss:  0.4323, val_acc:  0.8728
# Epoch 85 / 100, train_loss:  0.1631, train_acc: 0.9393, validation loss:  0.3880, val_acc:  0.8808
# Epoch 86 / 100, train_loss:  0.1670, train_acc: 0.9388, validation loss:  0.3949, val_acc:  0.8772
# Epoch 87 / 100, train_loss:  0.1663, train_acc: 0.9377, validation loss:  0.3991, val_acc:  0.8760
# Epoch 88 / 100, train_loss:  0.1656, train_acc: 0.9383, validation loss:  0.4349, val_acc:  0.8723
# Epoch 89 / 100, train_loss:  0.1697, train_acc: 0.9364, validation loss:  0.4254, val_acc:  0.8752
# Epoch 90 / 100, train_loss:  0.1619, train_acc: 0.9393, validation loss:  0.4331, val_acc:  0.8737
# Epoch 91 / 100, train_loss:  0.1612, train_acc: 0.9404, validation loss:  0.3868, val_acc:  0.8820
# Epoch 92 / 100, train_loss:  0.1503, train_acc: 0.9441, validation loss:  0.4449, val_acc:  0.8790
# Epoch 93 / 100, train_loss:  0.1646, train_acc: 0.9389, validation loss:  0.4359, val_acc:  0.8708
# Epoch 94 / 100, train_loss:  0.1716, train_acc: 0.9374, validation loss:  0.4028, val_acc:  0.8788
# Epoch 95 / 100, train_loss:  0.1545, train_acc: 0.9418, validation loss:  0.4514, val_acc:  0.8727
# Epoch 96 / 100, train_loss:  0.1538, train_acc: 0.9421, validation loss:  0.4226, val_acc:  0.8745
# Epoch 97 / 100, train_loss:  0.1567, train_acc: 0.9414, validation loss:  0.4524, val_acc:  0.8725
# Epoch 98 / 100, train_loss:  0.1504, train_acc: 0.9438, validation loss:  0.4073, val_acc:  0.8828
# Epoch 99 / 100, train_loss:  0.1443, train_acc: 0.9463, validation loss:  0.4465, val_acc:  0.8710
# Epoch 100 / 100, train_loss:  0.1512, train_acc: 0.9437, validation loss:  0.4250, val_acc:  0.8772

# %% [markdown]
# ### Present results

# %%
# Present results
fig, ax = plt.subplots(2, 2, figsize=(12, 10))
ax[0, 0].plot(train_loss_lst, color='green')
ax[0, 0].set(xlabel='Epoch', ylabel='Loss')
ax[0, 0].set_title('Training Loss')

ax[0, 1].plot(val_loss_lst, color='orange')
ax[0, 1].set(xlabel='Epoch', ylabel='Loss')
ax[0, 1].set_title('Validation Loss')

ax[1, 0].plot(train_acc_lst, color='green')
ax[1, 0].set(xlabel='Epoch', ylabel='Accuracy')
ax[1, 0].set_title('Training Accuracy')

ax[1, 1].plot(val_acc_lst, color='orange')
ax[1, 1].set(xlabel='Epoch', ylabel='Accuracy')
ax[1, 1].set_title('Validation Accuracy')

plt.show()

# %% [markdown]
# ### Evaluation

# %%
# Evaluation
test_target = []
test_predict = []
model.eval()
with torch.no_grad():
    for X_test, y_test in test_loader:
        X_test, y_test = X_test.to(device), y_test.to(device)
        outputs = model(X_test)

        test_predict.append(outputs.cpu())
        test_target.append(y_test.cpu())

    test_predict = torch.cat(test_predict)
    test_target = torch.cat(test_target)
    test_acc = (torch.argmax(test_predict, 1) ==
                test_target).sum().item()/len(test_target)

    print(f"Accuracy: {test_acc}")
    print("============================================================")
# Out:
# Accuracy: 0.8705
# ============================================================
